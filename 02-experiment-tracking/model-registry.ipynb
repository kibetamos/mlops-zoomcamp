# %% [markdown]
# ## MLflow's Model Registry

# %%
from mlflow.tracking import MlflowClient


MLFLOW_TRACKING_URI = "sqlite:///mlflow.db"

# %% [markdown]
# ### Interacting with the MLflow tracking server
#
# The `MlflowClient` object allows us to interact with...
# - an MLflow Tracking Server that creates and manages experiments and runs.
# - an MLflow Registry Server that creates and manages registered models and model versions.
#
# To instantiate it we need to pass a tracking URI and/or a registry URI

# %%
client = MlflowClient(tracking_uri=MLFLOW_TRACKING_URI)

client.list_experiments()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 3
#       1 client = MlflowClient(tracking_uri=MLFLOW_TRACKING_URI)
# ----> 3 client.list_experiments()
#
# AttributeError: 'MlflowClient' object has no attribute 'list_experiments'

# %%
client.create_experiment(name="my-cool-experiment")
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1969, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1968     if not evt_handled:
# -> 1969         self.dialect.do_execute(
#    1970             cursor, str_statement, effective_parameters, context
#    1971         )
#    1973 if self._has_events or self.engine._has_events:
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/default.py:922, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     921 def do_execute(self, cursor, statement, parameters, context=None):
# --> 922     cursor.execute(statement, parameters)
#
# IntegrityError: UNIQUE constraint failed: experiments.name
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/mlflow/store/tracking/sqlalchemy_store.py:279, in SqlAlchemyStore.create_experiment(self, name, artifact_location, tags)
#     277 if not artifact_location:
#     278     # this requires a double write. The first one to generate an autoincrement-ed ID
# --> 279     eid = session.query(SqlExperiment).filter_by(name=name).first().experiment_id
#     280     experiment.artifact_location = self._get_artifact_location(eid)
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/orm/query.py:2748, in Query.first(self)
#    2747 else:
# -> 2748     return self.limit(1)._iter().first()
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/orm/query.py:2847, in Query._iter(self)
#    2846 statement = self._statement_20()
# -> 2847 result: Union[ScalarResult[_T], Result[_T]] = self.session.execute(
#    2848     statement,
#    2849     params,
#    2850     execution_options={"_sa_orm_load_options": self.load_options},
#    2851 )
#    2853 # legacy: automatically set scalars, unique
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/orm/session.py:2308, in Session.execute(self, statement, params, execution_options, bind_arguments, _parent_execute_state, _add_event)
#    2257 r"""Execute a SQL expression construct.
#    2258
#    2259 Returns a :class:`_engine.Result` object representing
#    (...)
#    2306
#    2307 """
# -> 2308 return self._execute_internal(
#    2309     statement,
#    2310     params,
#    2311     execution_options=execution_options,
#    2312     bind_arguments=bind_arguments,
#    2313     _parent_execute_state=_parent_execute_state,
#    2314     _add_event=_add_event,
#    2315 )
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/orm/session.py:2169, in Session._execute_internal(self, statement, params, execution_options, bind_arguments, _parent_execute_state, _add_event, _scalar_result)
#    2160 if compile_state_cls is not None:
#    2161     # now run orm_pre_session_exec() "for real".   if there were
#    2162     # event hooks, this will re-run the steps that interpret
#    2163     # new execution_options into load_options / update_delete_options,
#    2164     # which we assume the event hook might have updated.
#    2165     # autoflush will also be invoked in this step if enabled.
#    2166     (
#    2167         statement,
#    2168         execution_options,
# -> 2169     ) = compile_state_cls.orm_pre_session_exec(
#    2170         self,
#    2171         statement,
#    2172         params,
#    2173         execution_options,
#    2174         bind_arguments,
#    2175         False,
#    2176     )
#    2178 bind = self.get_bind(**bind_arguments)
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/orm/context.py:551, in ORMCompileState.orm_pre_session_exec(cls, session, statement, params, execution_options, bind_arguments, is_pre_event)
#     550 if not is_pre_event and load_options._autoflush:
# --> 551     session._autoflush()
#     553 return statement, execution_options
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/orm/session.py:3021, in Session._autoflush(self)
#    3016 e.add_detail(
#    3017     "raised as a result of Query-invoked autoflush; "
#    3018     "consider using a session.no_autoflush block if this "
#    3019     "flush is occurring prematurely"
#    3020 )
# -> 3021 raise e.with_traceback(sys.exc_info()[2])
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/orm/session.py:3010, in Session._autoflush(self)
#    3009 try:
# -> 3010     self.flush()
#    3011 except sa_exc.StatementError as e:
#    3012     # note we are reraising StatementError as opposed to
#    3013     # raising FlushError with "chaining" to remain compatible
#    3014     # with code that catches StatementError, IntegrityError,
#    3015     # etc.
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/orm/session.py:4312, in Session.flush(self, objects)
#    4311     self._flushing = True
# -> 4312     self._flush(objects)
#    4313 finally:
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/orm/session.py:4447, in Session._flush(self, objects)
#    4446 except:
# -> 4447     with util.safe_reraise():
#    4448         transaction.rollback(_capture_exception=True)
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/util/langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/orm/session.py:4408, in Session._flush(self, objects)
#    4407 try:
# -> 4408     flush_context.execute()
#    4409 finally:
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/orm/unitofwork.py:466, in UOWTransaction.execute(self)
#     465 for rec in topological.sort(self.dependencies, postsort_actions):
# --> 466     rec.execute(self)
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/orm/unitofwork.py:642, in SaveUpdateAll.execute(self, uow)
#     640 @util.preload_module("sqlalchemy.orm.persistence")
#     641 def execute(self, uow):
# --> 642     util.preloaded.orm_persistence.save_obj(
#     643         self.mapper,
#     644         uow.states_for_mapper_hierarchy(self.mapper, False, False),
#     645         uow,
#     646     )
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/orm/persistence.py:93, in save_obj(base_mapper, states, uowtransaction, single)
#      85     _emit_update_statements(
#      86         base_mapper,
#      87         uowtransaction,
#    (...)
#      90         update,
#      91     )
# ---> 93     _emit_insert_statements(
#      94         base_mapper,
#      95         uowtransaction,
#      96         mapper,
#      97         table,
#      98         insert,
#      99     )
#     101 _finalize_insert_update_commands(
#     102     base_mapper,
#     103     uowtransaction,
#    (...)
#     119     ),
#     120 )
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/orm/persistence.py:1227, in _emit_insert_statements(base_mapper, uowtransaction, mapper, table, insert, bookkeeping, use_orm_insert_stmt, execution_options)
#    1226 else:
# -> 1227     result = connection.execute(
#    1228         statement,
#    1229         params,
#    1230         execution_options=execution_options,
#    1231     )
#    1233 primary_key = result.inserted_primary_key
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1416, in Connection.execute(self, statement, parameters, execution_options)
#    1415 else:
# -> 1416     return meth(
#    1417         self,
#    1418         distilled_parameters,
#    1419         execution_options or NO_OPTIONS,
#    1420     )
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/sql/elements.py:517, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     516         assert isinstance(self, Executable)
# --> 517     return connection._execute_clauseelement(
#     518         self, distilled_params, execution_options
#     519     )
#     520 else:
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1639, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1631 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1632     dialect=dialect,
#    1633     compiled_cache=compiled_cache,
#    (...)
#    1637     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1638 )
# -> 1639 ret = self._execute_context(
#    1640     dialect,
#    1641     dialect.execution_ctx_cls._init_compiled,
#    1642     compiled_sql,
#    1643     distilled_parameters,
#    1644     execution_options,
#    1645     compiled_sql,
#    1646     distilled_parameters,
#    1647     elem,
#    1648     extracted_params,
#    1649     cache_hit=cache_hit,
#    1650 )
#    1651 if has_events:
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1848, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1847 else:
# -> 1848     return self._exec_single_context(
#    1849         dialect, context, statement, parameters
#    1850     )
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1988, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1987 except BaseException as e:
# -> 1988     self._handle_dbapi_exception(
#    1989         e, str_statement, effective_parameters, cursor, context
#    1990     )
#    1992 return result
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:2344, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2343     assert sqlalchemy_exception is not None
# -> 2344     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2345 else:
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1969, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1968     if not evt_handled:
# -> 1969         self.dialect.do_execute(
#    1970             cursor, str_statement, effective_parameters, context
#    1971         )
#    1973 if self._has_events or self.engine._has_events:
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/default.py:922, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     921 def do_execute(self, cursor, statement, parameters, context=None):
# --> 922     cursor.execute(statement, parameters)
#
# IntegrityError: (raised as a result of Query-invoked autoflush; consider using a session.no_autoflush block if this flush is occurring prematurely)
# (sqlite3.IntegrityError) UNIQUE constraint failed: experiments.name
# [SQL: INSERT INTO experiments (name, artifact_location, lifecycle_stage, creation_time, last_update_time) VALUES (?, ?, ?, ?, ?)]
# [parameters: ('my-cool-experiment', None, 'active', 1716988906236, 1716988906236)]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
#
# During handling of the above exception, another exception occurred:
#
# MlflowException                           Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 client.create_experiment(name="my-cool-experiment")
#
# File ~/anaconda3/lib/python3.11/site-packages/mlflow/tracking/client.py:1258, in MlflowClient.create_experiment(self, name, artifact_location, tags)
#    1206 def create_experiment(
#    1207     self,
#    1208     name: str,
#    1209     artifact_location: Optional[str] = None,
#    1210     tags: Optional[Dict[str, Any]] = None,
#    1211 ) -> str:
#    1212     """Create an experiment.
#    1213
#    1214     Args:
#    (...)
#    1256
#    1257     """
# -> 1258     return self._tracking_client.create_experiment(name, artifact_location, tags)
#
# File ~/anaconda3/lib/python3.11/site-packages/mlflow/tracking/_tracking_service/client.py:499, in TrackingServiceClient.create_experiment(self, name, artifact_location, tags)
#     484 """Create an experiment.
#     485
#     486 Args:
#    (...)
#     495
#     496 """
#     497 _validate_experiment_artifact_location(artifact_location)
# --> 499 return self.store.create_experiment(
#     500     name=name,
#     501     artifact_location=artifact_location,
#     502     tags=[ExperimentTag(key, value) for (key, value) in tags.items()] if tags else [],
#     503 )
#
# File ~/anaconda3/lib/python3.11/site-packages/mlflow/store/tracking/sqlalchemy_store.py:282, in SqlAlchemyStore.create_experiment(self, name, artifact_location, tags)
#     280         experiment.artifact_location = self._get_artifact_location(eid)
#     281 except sqlalchemy.exc.IntegrityError as e:
# --> 282     raise MlflowException(
#     283         f"Experiment(name={name}) already exists. Error: {e}",
#     284         RESOURCE_ALREADY_EXISTS,
#     285     )
#     287 session.flush()
#     288 return str(experiment.experiment_id)
#
# MlflowException: Experiment(name=my-cool-experiment) already exists. Error: (raised as a result of Query-invoked autoflush; consider using a session.no_autoflush block if this flush is occurring prematurely)
# (sqlite3.IntegrityError) UNIQUE constraint failed: experiments.name
# [SQL: INSERT INTO experiments (name, artifact_location, lifecycle_stage, creation_time, last_update_time) VALUES (?, ?, ?, ?, ?)]
# [parameters: ('my-cool-experiment', None, 'active', 1716988906236, 1716988906236)]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)

# %% [markdown]
# Let's check the latest versions for the experiment with id `1`...

# %%
from mlflow.entities import ViewType

runs = client.search_runs(
    experiment_ids='1',
    filter_string="metrics.rmse < 7",
    run_view_type=ViewType.ACTIVE_ONLY,
    max_results=5,
    order_by=["metrics.rmse ASC"]
)

# %%
for run in runs:
    print(f"run id: {run.info.run_id}, rmse: {run.data.metrics['rmse']:.4f}")

# %% [markdown]
# ### Interacting with the Model Registry
#
# In this section We will use the `MlflowClient` instance to:
#
# 1. Register a new version for the experiment `nyc-taxi-regressor`
# 2. Retrieve the latests versions of the model `nyc-taxi-regressor` and check that a new version `4` was created.
# 3. Transition the version `4` to "Staging" and adding annotations to it.

# %%
import mlflow

mlflow.set_tracking_uri(MLFLOW_TRACKING_URI)

# %%
run_id = "b8904012c84343b5bf8ee72aa8f0f402"
model_uri = f"runs:/{run_id}/model"
mlflow.register_model(model_uri=model_uri, name="nyc-taxi-regressor")
# Out:
# Successfully registered model 'nyc-taxi-regressor'.
# ---------------------------------------------------------------------------
# MlflowException                           Traceback (most recent call last)
# Cell In[8], line 3
#       1 run_id = "b8904012c84343b5bf8ee72aa8f0f402"
#       2 model_uri = f"runs:/{run_id}/model"
# ----> 3 mlflow.register_model(model_uri=model_uri, name="nyc-taxi-regressor")
#
# File ~/anaconda3/lib/python3.11/site-packages/mlflow/tracking/_model_registry/fluent.py:77, in register_model(model_uri, name, await_registration_for, tags)
#      17 def register_model(
#      18     model_uri,
#      19     name,
#    (...)
#      22     tags: Optional[Dict[str, Any]] = None,
#      23 ) -> ModelVersion:
#      24     """Create a new model version in model registry for the model files specified by ``model_uri``.
#      25
#      26     Note that this method assumes the model registry backend URI is the same as that of the
#    (...)
#      75         Version: 1
#      76     """
# ---> 77     return _register_model(
#      78         model_uri=model_uri, name=name, await_registration_for=await_registration_for, tags=tags
#      79     )
#
# File ~/anaconda3/lib/python3.11/site-packages/mlflow/tracking/_model_registry/fluent.py:109, in _register_model(model_uri, name, await_registration_for, tags, local_model_path)
#     107 source = model_uri
#     108 if RunsArtifactRepository.is_runs_uri(model_uri):
# --> 109     source = RunsArtifactRepository.get_underlying_uri(model_uri)
#     110     (run_id, _) = RunsArtifactRepository.parse_runs_uri(model_uri)
#     112 create_version_response = client._create_model_version(
#     113     name=name,
#     114     source=source,
#    (...)
#     118     local_model_path=local_model_path,
#     119 )
#
# File ~/anaconda3/lib/python3.11/site-packages/mlflow/store/artifact/runs_artifact_repo.py:39, in RunsArtifactRepository.get_underlying_uri(runs_uri)
#      37 (run_id, artifact_path) = RunsArtifactRepository.parse_runs_uri(runs_uri)
#      38 tracking_uri = get_databricks_profile_uri_from_artifact_uri(runs_uri)
# ---> 39 uri = get_artifact_uri(run_id, artifact_path, tracking_uri)
#      40 assert not RunsArtifactRepository.is_runs_uri(uri)  # avoid an infinite loop
#      41 return add_databricks_profile_info_to_artifact_uri(uri, tracking_uri)
#
# File ~/anaconda3/lib/python3.11/site-packages/mlflow/tracking/artifact_utils.py:52, in get_artifact_uri(run_id, artifact_path, tracking_uri)
#      46     raise MlflowException(
#      47         message="A run_id must be specified in order to obtain an artifact uri!",
#      48         error_code=INVALID_PARAMETER_VALUE,
#      49     )
#      51 store = _get_store(tracking_uri)
# ---> 52 run = store.get_run(run_id)
#      53 # Maybe move this method to RunsArtifactRepository so the circular dependency is clearer.
#      54 assert urllib.parse.urlparse(run.info.artifact_uri).scheme != "runs"  # avoid an infinite loop
#
# File ~/anaconda3/lib/python3.11/site-packages/mlflow/store/tracking/sqlalchemy_store.py:638, in SqlAlchemyStore.get_run(self, run_id)
#     632 def get_run(self, run_id):
#     633     with self.ManagedSessionMaker() as session:
#     634         # Load the run with the specified id and eagerly load its summary metrics, params, and
#     635         # tags. These attributes are referenced during the invocation of
#     636         # ``run.to_mlflow_entity()``, so eager loading helps avoid additional database queries
#     637         # that are otherwise executed at attribute access time under a lazy loading model.
# --> 638         run = self._get_run(run_uuid=run_id, session=session, eager=True)
#     639         mlflow_run = run.to_mlflow_entity()
#     640         # Get the run inputs and add to the run
#
# File ~/anaconda3/lib/python3.11/site-packages/mlflow/store/tracking/sqlalchemy_store.py:522, in SqlAlchemyStore._get_run(self, session, run_uuid, eager)
#     517 runs = (
#     518     session.query(SqlRun).options(*query_options).filter(SqlRun.run_uuid == run_uuid).all()
#     519 )
#     521 if len(runs) == 0:
# --> 522     raise MlflowException(f"Run with id={run_uuid} not found", RESOURCE_DOES_NOT_EXIST)
#     523 if len(runs) > 1:
#     524     raise MlflowException(
#     525         f"Expected only 1 run with id={run_uuid}. Found {len(runs)}.",
#     526         INVALID_STATE,
#     527     )
#
# MlflowException: Run with id=b8904012c84343b5bf8ee72aa8f0f402 not found

# %%
model_name = "nyc-taxi-regressor"
latest_versions = client.get_latest_versions(name=model_name)

for version in latest_versions:
    print(f"version: {version.version}, stage: {version.current_stage}")
# Out:
# /tmp/ipykernel_331264/669935608.py:2: FutureWarning: ``mlflow.tracking.client.MlflowClient.get_latest_versions`` is deprecated since 2.9.0. Model registry stages will be removed in a future major release. To learn more about the deprecation of model registry stages, see our migration guide here: https://mlflow.org/docs/2.13.0/model-registry.html#migrating-from-stages
#   latest_versions = client.get_latest_versions(name=model_name)

# %%
model_version = 4
new_stage = "Staging"
client.transition_model_version_stage(
    name=model_name,
    version=model_version,
    stage=new_stage,
    archive_existing_versions=False
)
# Out:
# /tmp/ipykernel_331264/1718116654.py:3: FutureWarning: ``mlflow.tracking.client.MlflowClient.transition_model_version_stage`` is deprecated since 2.9.0. Model registry stages will be removed in a future major release. To learn more about the deprecation of model registry stages, see our migration guide here: https://mlflow.org/docs/2.13.0/model-registry.html#migrating-from-stages
#   client.transition_model_version_stage(
# ---------------------------------------------------------------------------
# MlflowException                           Traceback (most recent call last)
# Cell In[10], line 3
#       1 model_version = 4
#       2 new_stage = "Staging"
# ----> 3 client.transition_model_version_stage(
#       4     name=model_name,
#       5     version=model_version,
#       6     stage=new_stage,
#       7     archive_existing_versions=False
#       8 )
#
# File ~/anaconda3/lib/python3.11/site-packages/mlflow/utils/annotations.py:145, in deprecated.<locals>.deprecated_decorator.<locals>.deprecated_func(*args, **kwargs)
#     142 @wraps(func)
#     143 def deprecated_func(*args, **kwargs):
#     144     warnings.warn(notice, category=FutureWarning, stacklevel=2)
# --> 145     return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/mlflow/tracking/client.py:3906, in MlflowClient.transition_model_version_stage(self, name, version, stage, archive_existing_versions)
#    3831 @deprecated(since="2.9.0", impact=_STAGES_DEPRECATION_WARNING)
#    3832 def transition_model_version_stage(
#    3833     self, name: str, version: str, stage: str, archive_existing_versions: bool = False
#    3834 ) -> ModelVersion:
#    3835     """
#    3836     Update model version stage.
#    3837
#    (...)
#    3904         Stage: Staging
#    3905     """
# -> 3906     return self._get_registry_client().transition_model_version_stage(
#    3907         name, version, stage, archive_existing_versions
#    3908     )
#
# File ~/anaconda3/lib/python3.11/site-packages/mlflow/tracking/_model_registry/client.py:277, in ModelRegistryClient.transition_model_version_stage(self, name, version, stage, archive_existing_versions)
#     275 if stage.strip() == "":
#     276     raise MlflowException("The stage must not be an empty string.")
# --> 277 return self.store.transition_model_version_stage(
#     278     name=name,
#     279     version=version,
#     280     stage=stage,
#     281     archive_existing_versions=archive_existing_versions,
#     282 )
#
# File ~/anaconda3/lib/python3.11/site-packages/mlflow/store/model_registry/sqlalchemy_store.py:854, in SqlAlchemyStore.transition_model_version_stage(self, name, version, stage, archive_existing_versions)
#     851         mv.current_stage = STAGE_ARCHIVED
#     852         mv.last_updated_time = last_updated_time
# --> 854 sql_model_version = self._get_sql_model_version(
#     855     session=session, name=name, version=version
#     856 )
#     857 sql_model_version.current_stage = get_canonical_stage(stage)
#     858 sql_model_version.last_updated_time = last_updated_time
#
# File ~/anaconda3/lib/python3.11/site-packages/mlflow/store/model_registry/sqlalchemy_store.py:767, in SqlAlchemyStore._get_sql_model_version(cls, session, name, version, eager)
#     761 query_options = cls._get_eager_model_version_query_options() if eager else []
#     762 conditions = [
#     763     SqlModelVersion.name == name,
#     764     SqlModelVersion.version == version,
#     765     SqlModelVersion.current_stage != STAGE_DELETED_INTERNAL,
#     766 ]
# --> 767 return cls._get_model_version_from_db(session, name, version, conditions, query_options)
#
# File ~/anaconda3/lib/python3.11/site-packages/mlflow/store/model_registry/sqlalchemy_store.py:738, in SqlAlchemyStore._get_model_version_from_db(cls, session, name, version, conditions, query_options)
#     735 versions = session.query(SqlModelVersion).options(*query_options).filter(*conditions).all()
#     737 if len(versions) == 0:
# --> 738     raise MlflowException(
#     739         f"Model Version (name={name}, version={version}) not found",
#     740         RESOURCE_DOES_NOT_EXIST,
#     741     )
#     742 if len(versions) > 1:
#     743     raise MlflowException(
#     744         f"Expected only 1 model version with (name={name}, version={version}). "
#     745         f"Found {len(versions)}.",
#     746         INVALID_STATE,
#     747     )
#
# MlflowException: Model Version (name=nyc-taxi-regressor, version=4) not found

# %%
from datetime import datetime

date = datetime.today().date()
client.update_model_version(
    name=model_name,
    version=model_version,
    description=f"The model version {model_version} was transitioned to {new_stage} on {date}"
)
# Out:
# ---------------------------------------------------------------------------
# MlflowException                           Traceback (most recent call last)
# Cell In[11], line 4
#       1 from datetime import datetime
#       3 date = datetime.today().date()
# ----> 4 client.update_model_version(
#       5     name=model_name,
#       6     version=model_version,
#       7     description=f"The model version {model_version} was transitioned to {new_stage} on {date}"
#       8 )
#
# File ~/anaconda3/lib/python3.11/site-packages/mlflow/tracking/client.py:3827, in MlflowClient.update_model_version(self, name, version, description)
#    3824 if description is None:
#    3825     raise MlflowException("Attempting to update model version with no new field values.")
# -> 3827 return self._get_registry_client().update_model_version(
#    3828     name=name, version=version, description=description
#    3829 )
#
# File ~/anaconda3/lib/python3.11/site-packages/mlflow/tracking/_model_registry/client.py:257, in ModelRegistryClient.update_model_version(self, name, version, description)
#     249 def update_model_version(self, name, version, description):
#     250     """Update metadata associated with a model version in backend.
#     251
#     252     Args:
#    (...)
#     255         description: New description.
#     256     """
# --> 257     return self.store.update_model_version(name=name, version=version, description=description)
#
# File ~/anaconda3/lib/python3.11/site-packages/mlflow/store/model_registry/sqlalchemy_store.py:806, in SqlAlchemyStore.update_model_version(self, name, version, description)
#     804 with self.ManagedSessionMaker() as session:
#     805     updated_time = get_current_time_millis()
# --> 806     sql_model_version = self._get_sql_model_version(session, name=name, version=version)
#     807     sql_model_version.description = description
#     808     sql_model_version.last_updated_time = updated_time
#
# File ~/anaconda3/lib/python3.11/site-packages/mlflow/store/model_registry/sqlalchemy_store.py:767, in SqlAlchemyStore._get_sql_model_version(cls, session, name, version, eager)
#     761 query_options = cls._get_eager_model_version_query_options() if eager else []
#     762 conditions = [
#     763     SqlModelVersion.name == name,
#     764     SqlModelVersion.version == version,
#     765     SqlModelVersion.current_stage != STAGE_DELETED_INTERNAL,
#     766 ]
# --> 767 return cls._get_model_version_from_db(session, name, version, conditions, query_options)
#
# File ~/anaconda3/lib/python3.11/site-packages/mlflow/store/model_registry/sqlalchemy_store.py:738, in SqlAlchemyStore._get_model_version_from_db(cls, session, name, version, conditions, query_options)
#     735 versions = session.query(SqlModelVersion).options(*query_options).filter(*conditions).all()
#     737 if len(versions) == 0:
# --> 738     raise MlflowException(
#     739         f"Model Version (name={name}, version={version}) not found",
#     740         RESOURCE_DOES_NOT_EXIST,
#     741     )
#     742 if len(versions) > 1:
#     743     raise MlflowException(
#     744         f"Expected only 1 model version with (name={name}, version={version}). "
#     745         f"Found {len(versions)}.",
#     746         INVALID_STATE,
#     747     )
#
# MlflowException: Model Version (name=nyc-taxi-regressor, version=4) not found

# %% [markdown]
# ### Comparing versions and selecting the new "Production" model
#
# In the last section, we will retrieve models registered in the model registry and compare their performance on an unseen test set. The idea is to simulate the scenario in which a deployment engineer has to interact with the model registry to decide whether to update the model version that is in production or not.
#
# These are the steps:
#
# 1. Load the test dataset, which corresponds to the NYC Green Taxi data from the month of March 2021.
# 2. Download the `DictVectorizer` that was fitted using the training data and saved to MLflow as an artifact, and load it with pickle.
# 3. Preprocess the test set using the `DictVectorizer` so we can properly feed the regressors.
# 4. Make predictions on the test set using the model versions that are currently in the "Staging" and "Production" stages, and compare their performance.
# 5. Based on the results, update the "Production" model version accordingly.
#
#
# **Note: the model registry doesn't actually deploy the model to production when you transition a model to the "Production" stage, it just assign a label to that model version. You should complement the registry with some CI/CD code that does the actual deployment.**

# %%
from sklearn.metrics import mean_squared_error
import pandas as pd


def read_dataframe(filename):
    df = pd.read_csv(filename)

    df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
    df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)

    df['duration'] = df.lpep_dropoff_datetime - df.lpep_pickup_datetime
    df.duration = df.duration.apply(lambda td: td.total_seconds() / 60)

    df = df[(df.duration >= 1) & (df.duration <= 60)]

    categorical = ['PULocationID', 'DOLocationID']
    df[categorical] = df[categorical].astype(str)
    
    return df


def preprocess(df, dv):
    df['PU_DO'] = df['PULocationID'] + '_' + df['DOLocationID']
    categorical = ['PU_DO']
    numerical = ['trip_distance']
    train_dicts = df[categorical + numerical].to_dict(orient='records')
    return dv.transform(train_dicts)


def test_model(name, stage, X_test, y_test):
    model = mlflow.pyfunc.load_model(f"models:/{name}/{stage}")
    y_pred = model.predict(X_test)
    return {"rmse": mean_squared_error(y_test, y_pred, squared=False)}

# %%
df = read_dataframe("data/green_tripdata_2021-03.csv")
# Out:
# /var/folders/42/f9s_rgk15078ym2w50_xtc180000gq/T/ipykernel_5486/3050441246.py:6: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename)

# %%
client.download_artifacts(run_id=run_id, path='preprocessor', dst_path='.')
# Out:
# '/Users/cristian.martinez/Repositories/mlops-zoomcamp/02-experiment-tracking/preprocessor'

# %%
import pickle

with open("preprocessor/preprocessor.b", "rb") as f_in:
    dv = pickle.load(f_in)

# %%
X_test = preprocess(df, dv)

# %%
target = "duration"
y_test = df[target].values

# %%
# %time test_model(name=model_name, stage="Production", X_test=X_test, y_test=y_test)
# Out:
# CPU times: user 139 ms, sys: 44.6 ms, total: 183 ms
# Wall time: 447 ms
# {'rmse': 6.659623830022514}

# %%
# %time test_model(name=model_name, stage="Staging", X_test=X_test, y_test=y_test)
# Out:
# CPU times: user 6.94 s, sys: 216 ms, total: 7.16 s
# Wall time: 7.28 s
# {'rmse': 6.881555517147188}

# %%
client.transition_model_version_stage(
    name=model_name,
    version=4,
    stage="Production",
    archive_existing_versions=True
)
# Out:
# <ModelVersion: creation_timestamp=1652971637398, current_stage='Production', description='The model version 4 was transitioned to Staging on 2022-05-19', last_updated_timestamp=1652972763255, name='nyc-taxi-regressor', run_id='b8904012c84343b5bf8ee72aa8f0f402', run_link=None, source='./mlruns/1/b8904012c84343b5bf8ee72aa8f0f402/artifacts/model', status='READY', status_message=None, tags={}, user_id=None, version=4>
